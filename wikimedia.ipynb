# %%
pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (4.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from pyspark) (0.10.9.9)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (2.32.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)

# %%
pip install sseclient
# Out:
# Requirement already satisfied: sseclient in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (0.0.27)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.9 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from sseclient) (2.32.3)
# Requirement already satisfied: six in c:\users\tomer cohen\appdata\roaming\python\python313\site-packages (from sseclient) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.9->sseclient) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.9->sseclient) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.9->sseclient) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.9->sseclient) (2024.12.14)

# %%
import os
import pyspark
import threading
import time
from kafka import KafkaConsumer
from kafka import KafkaProducer
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json, expr
from pyspark.sql.types import StructType, StringType, IntegerType
from pyspark.streaming import StreamingContext

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = f'--packages org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__} pyspark-shell'
os.environ['SPARK_SUBMIT_OPTS'] = '-Djdk.security.auth.login.Config=ignore'

# %%
KAFKA_BROKER_URL = "localhost:9092"
KAFKA_TOPIC = "wikimedia_topic_1"

# %%
# *** Note!!! **** At this point you need to have Kafka broker running. See Setup for Docker and Kafka.

producer = KafkaProducer(bootstrap_servers=KAFKA_BROKER_URL)

# %%
import requests
from sseclient import SSEClient
URL = 'https://stream.wikimedia.org/v2/stream/recentchange'
headers = {
    "User-Agent": "big_data",
    "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....bLWOUdFqZJu2_WxXK5S5iokZxs_rhnTN8Ss64WC9ynRmcAXyS0fDvJ9TDyqOfSR9kxI_k9REXphFkqaM2r2Qe8MpzbjLRk2IVE_B9SjtlfLerch7rkY8Ust_AP1MQn4zi-qZPou_Z2gIa5cOArrxGKNW3JlWemP6Vfhu0WdvDFwO-u9VmaFshsyvBzQS6UBAS8JADLstC-t3IL5GV3GkcjMfx-okJ0TOPFLSI6j0_MXD7yWHOD2gYH2kCQcS4gO28T2vUWg_tFxX8oKvpEgMFkd3dfAWn546u-I30yIqcLw-a0a0e3Kdn3OGAZsd8Kbz1W1RJ1MWy6OgrQkFxjI0mwHrhUKbO5jL1Q51PuA8MJ_REKTWxrmqYWxzQis_xzg_WhgLPChmUbrP1_iaxJJRETcU9zAk0Fa2Y-56s5w3KbiYMSMjSs2-d32MBIqiAfkTr5hqeiU5Pr7wFXasl8IOZv9GHPfYNuVHEbD8-9KEorrBVs68aw1o5Y6Cw0FsFiV811S4oZN5keT89IegiNC_G1GZ56n-SO4XgftQyNwS7bbqvD8ZybvU8bfZeDjEiDhv2RaD5VO2aawkjLik-0ra6suSnKQkRCCFx8Z1DYsyo9FkSgMi45SEqy06DYVh3k7oTiBVCWE3Ur7sYNbPdsrDJN_I-Y9JFhOo1JNNsg8As3A"
}
def relay():
    events = SSEClient(URL, headers=headers, timeout=30)
    for i in range(100):
        for event in events:
            if event.event == 'message' and event.data != None:
                message = event.data.encode("utf-8")
                producer.send(KAFKA_TOPIC, value=message)
                break
threading.Thread(target=relay).start()

# %%
# *** Note!!! **** Before continue to the next phase, make sure that you have a topic and events in it.
# See 'Lookup Kafka Topics' in the Readme.

spark = SparkSession.builder \
    .appName("PySpark-jupyter-streaming") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__}") \
    .config("spark.sql.streaming.checkpointLocation", "./checkpoint") \
    .getOrCreate()

# %%
# Original streaming code:
# kafka_df = spark.readStream \
#   .format("kafka") \
#   .option("kafka.bootstrap.servers", KAFKA_BROKER_URL) \
#   .option("subscribe", KAFKA_TOPIC) \
#   .option("startingOffsets", "earliest") \
#   .load()

# Batch mode (works on Windows):
kafka_df = spark.read \
    .format("kafka") \
    .option("kafka.bootstrap.servers", KAFKA_BROKER_URL) \
    .option("subscribe", KAFKA_TOPIC) \
    .option("startingOffsets", "earliest") \
    .option("endingOffsets", "latest") \
    .load()

print(f"Total messages in Kafka topic: {kafka_df.count()}")
# Out:
# Total messages in Kafka topic: 900

# %%
schema = StructType() \
    .add("id", IntegerType()) \
    .add("type", StringType()) \
    .add("comment", StringType()) \
    .add("user", StringType()) \
    .add("title", StringType()) \
    .add("server_name", StringType())

# Transform data to dataframe of json format
parsed_df = kafka_df.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), schema).alias("data")) \
    .select("data.*")

print(f"Parsed {parsed_df.count()} records")
parsed_df.show(10, truncate=False)
# Out:
# Parsed 900 records
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+
# |id        |type      |comment                                                                                                                                                                |user            |title                                                      |server_name          |
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+
# |NULL      |NULL      |NULL                                                                                                                                                                   |NULL            |NULL                                                       |NULL                 |
# |72686681  |categorize|[[:Ла Парита (Санта Барбара)]] категори чу тоьхна                                                                                                                      |CheWikibot      |Категори:ISBN хьажоргаш лелош йолу агӀонаш                 |ce.wikipedia.org     |
# |NULL      |categorize|[[:File:Monument to the Unelected001.JPG]] added to category                                                                                                           |Rkieferbot      |Category:Taken with Canon PowerShot SX110 IS               |commons.wikimedia.org|
# |88311654  |edit      |/* קישורים חיצוניים */ קישור ארכיון והשלמת פרמטרים                                                                                                                     |לאמילה          |אבולוציה של סילוניות                                       |he.wikipedia.org     |
# |72686682  |new       |Page creation                                                                                                                                                          |CheWikibot      |Ла Парита (Сатево)                                         |ce.wikipedia.org     |
# |1986867487|edit      |Relisting [[:Wikipedia:Articles for deletion/Harrier LR5]] ([[WP:XFDC#4.0.16|XFDcloser]])                                                                              |WikiMacaroons   |Wikipedia:Articles for deletion/Log/2026 January 17        |en.wikipedia.org     |
# |NULL      |edit      |/* wbsetclaim-create:1||1 */ [[d:Special:EntityPage/P1163]]: image/jpeg, BOT - Adding [[Commons:Structured data|structured data]] based on file information: media type|Emijrpbot       |File:TWU Gymnastics (Floor) Amy Winczura (5694662658).jpg  |commons.wikimedia.org|
# |NULL      |edit      |/* wbcreateclaim-create:1| */ [[Property:P373]]: Fraunhoferstraße 8 (München), #quickstatements; #temporary_batch_1768650407439                                        |M2k~dewiki      |Q41178673                                                  |www.wikidata.org     |
# |76305160  |edit      |удаление мусора из кода (через [[:en:w:WP:JWB|JWB]])                                                                                                                   |Well, Well, Bot!|МВД России одобряет идею сажать киберпреступников на 10 лет|ru.wikinews.org      |
# |NULL      |edit      |/* wbsetlabel-add:1|sv */ Kategori:Sport i Storbritannien 1947 efter månad                                                                                             |J 1982          |Q137502397                                                 |www.wikidata.org     |
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+
# only showing top 10 rows

# %%
# Original streaming code:
# parsed_df.writeStream \
#     .outputMode("append") \
#     .format("console") \
#     .start()

# Batch mode - create temp view and show data:
parsed_df.createOrReplaceTempView("wikimedia_changes")
print("Sample data:")
spark.sql("SELECT * FROM wikimedia_changes LIMIT 10").show(truncate=False)
# Out:
# Sample data:
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+
# |id        |type      |comment                                                                                                                                                                |user            |title                                                      |server_name          |
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+
# |NULL      |NULL      |NULL                                                                                                                                                                   |NULL            |NULL                                                       |NULL                 |
# |72686681  |categorize|[[:Ла Парита (Санта Барбара)]] категори чу тоьхна                                                                                                                      |CheWikibot      |Категори:ISBN хьажоргаш лелош йолу агӀонаш                 |ce.wikipedia.org     |
# |NULL      |categorize|[[:File:Monument to the Unelected001.JPG]] added to category                                                                                                           |Rkieferbot      |Category:Taken with Canon PowerShot SX110 IS               |commons.wikimedia.org|
# |88311654  |edit      |/* קישורים חיצוניים */ קישור ארכיון והשלמת פרמטרים                                                                                                                     |לאמילה          |אבולוציה של סילוניות                                       |he.wikipedia.org     |
# |72686682  |new       |Page creation                                                                                                                                                          |CheWikibot      |Ла Парита (Сатево)                                         |ce.wikipedia.org     |
# |1986867487|edit      |Relisting [[:Wikipedia:Articles for deletion/Harrier LR5]] ([[WP:XFDC#4.0.16|XFDcloser]])                                                                              |WikiMacaroons   |Wikipedia:Articles for deletion/Log/2026 January 17        |en.wikipedia.org     |
# |NULL      |edit      |/* wbsetclaim-create:1||1 */ [[d:Special:EntityPage/P1163]]: image/jpeg, BOT - Adding [[Commons:Structured data|structured data]] based on file information: media type|Emijrpbot       |File:TWU Gymnastics (Floor) Amy Winczura (5694662658).jpg  |commons.wikimedia.org|
# |NULL      |edit      |/* wbcreateclaim-create:1| */ [[Property:P373]]: Fraunhoferstraße 8 (München), #quickstatements; #temporary_batch_1768650407439                                        |M2k~dewiki      |Q41178673                                                  |www.wikidata.org     |
# |76305160  |edit      |удаление мусора из кода (через [[:en:w:WP:JWB|JWB]])                                                                                                                   |Well, Well, Bot!|МВД России одобряет идею сажать киберпреступников на 10 лет|ru.wikinews.org      |
# |NULL      |edit      |/* wbsetlabel-add:1|sv */ Kategori:Sport i Storbritannien 1947 efter månad                                                                                             |J 1982          |Q137502397                                                 |www.wikidata.org     |
# +----------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-----------------------------------------------------------+---------------------+

# %%
# Original streaming code:
# parsed_df.createOrReplaceTempView("parsed_df")
# spark.sql("select user, count(*) as count from parsed_df group by user") \
# .writeStream \
# .outputMode("complete") \
# .format("console") \
# .start()

# Batch mode:
print("Edits by user:")
spark.sql("""
    SELECT user, COUNT(*) as count 
    FROM wikimedia_changes 
    GROUP BY user 
    ORDER BY count DESC
    LIMIT 10
""").show(truncate=False)
# Out:
# Edits by user:
# +------------------+-----+
# |user              |count|
# +------------------+-----+
# |PantheraLeo1359531|134  |
# |CheWikibot        |92   |
# |DPLA bot          |70   |
# |Rkieferbot        |48   |
# |Emijrpbot         |48   |
# |ROCKY             |28   |
# |Brunaldo Bruno    |26   |
# |Ladsgroup         |26   |
# |Shakko            |14   |
# |GrandDukeMarcelo  |14   |
# +------------------+-----+

# %%
# Original streaming code:
# spark.sql("select type, count(*) as count from parsed_df group by type") \
# .writeStream \
# .outputMode("complete") \
# .format("console") \
# .start()

# Batch mode:
print("Edits by type:")
spark.sql("""
    SELECT type, COUNT(*) as count 
    FROM wikimedia_changes 
    GROUP BY type 
    ORDER BY count DESC
""").show(truncate=False)
# Out:
# Edits by type:
# +----------+-----+
# |type      |count|
# +----------+-----+
# |categorize|465  |
# |edit      |330  |
# |log       |68   |
# |new       |25   |
# |NULL      |12   |
# +----------+-----+
