# %% [markdown]
# # Electric Vehicle Population - Spark Structured Streaming
# This notebook consumes EV data from Kafka and performs streaming analytics.

# %%
pip install kafka-python pyspark
# Out:
# Requirement already satisfied: kafka-python in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Requirement already satisfied: pyspark in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (4.1.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\tomer cohen\appdata\local\programs\python\python313\lib\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
import uuid
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, from_json, count, desc
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, BooleanType, DoubleType

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = f'--packages org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__} pyspark-shell'
os.environ['SPARK_SUBMIT_OPTS'] = '-Djdk.security.auth.login.Config=ignore'

# %%
KAFKA_BROKER_URL = "localhost:9092"
KAFKA_TOPIC = "electric-cars"

# %%
# Create SparkSession
# Note: Using a unique checkpoint dir to avoid stale checkpoint issues
import uuid
checkpoint_dir = f"./checkpoint_ev_{uuid.uuid4().hex[:8]}"

spark = SparkSession.builder \
    .appName("ElectricVehicles-Streaming") \
    .config("spark.jars.packages", f"org.apache.spark:spark-sql-kafka-0-10_2.13:{pyspark.__version__}") \
    .config("spark.sql.streaming.checkpointLocation", checkpoint_dir) \
    .getOrCreate()

print(f"Checkpoint location: {checkpoint_dir}")
# Out:
# Checkpoint location: ./checkpoint_ev_9cdb878d

# %%
# Schema matching the cleaned data from producer.py
ev_schema = StructType([
    StructField("vin", StringType(), True),
    StructField("county", StringType(), True),
    StructField("city", StringType(), True),
    StructField("state", StringType(), True),
    StructField("postal_code", StringType(), True),
    StructField("make", StringType(), True),
    StructField("model", StringType(), True),
    StructField("electric_vehicle_type", StringType(), True),
    StructField("cafv_eligibility", StringType(), True),
    StructField("electric_utility", StringType(), True),
    StructField("model_year", IntegerType(), True),
    StructField("electric_range", IntegerType(), True),
    StructField("base_msrp", IntegerType(), True),
    StructField("legislative_district", IntegerType(), True),
    StructField("dol_vehicle_id", IntegerType(), True),
    StructField("census_tract", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("is_bev", BooleanType(), True),
    StructField("range_category", StringType(), True),
    StructField("is_cafv_eligible", BooleanType(), True)
])

# %%
# DEBUG: First read raw Kafka data (batch mode) to verify messages exist
# This reads WITHOUT streaming to check if topic has data
try:
    raw_batch = spark.read \
        .format("kafka") \
        .option("kafka.bootstrap.servers", KAFKA_BROKER_URL) \
        .option("subscribe", KAFKA_TOPIC) \
        .option("startingOffsets", "earliest") \
        .option("endingOffsets", "latest") \
        .load()
    
    print(f"Total messages in Kafka topic: {raw_batch.count()}")
    print("\nSample raw messages:")
    raw_batch.selectExpr("CAST(value AS STRING) as raw_json").show(5, truncate=False)
except Exception as e:
    print(f"Error reading from Kafka: {e}")
    print("Make sure Kafka is running and the topic exists!")
# Out:
# Total messages in Kafka topic: 633845
#
# Sample raw messages:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |raw_json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"vin": "KM8K33AGXL", "county": "King", "city": "Seattle", "state": "WA", "postal_code": "98103", "make": "HYUNDAI", "model": "KONA", "electric_vehicle_type": "Battery Electric Vehicle (BEV)", "cafv_eligibility": "Clean Alternative Fuel Vehicle Eligible", "electric_utility": "CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)", "model_year": 2020, "electric_range": 258, "base_msrp": 0, "legislative_district": 43, "dol_vehicle_id": 249675142, "census_tract": "53033004800", "latitude": 47.659185, "longitude": -122.34301, "is_bev": true, "range_category": "Long Range", "is_cafv_eligible": true}               |
# |{"vin": "1C4RJYB61N", "county": "King", "city": "Bothell", "state": "WA", "postal_code": "98011", "make": "JEEP", "model": "GRAND CHEROKEE", "electric_vehicle_type": "Plug-in Hybrid Electric Vehicle (PHEV)", "cafv_eligibility": "Not eligible due to low battery range", "electric_utility": "PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)", "model_year": 2022, "electric_range": 25, "base_msrp": 0, "legislative_district": 1, "dol_vehicle_id": 233928502, "census_tract": "53033021804", "latitude": 47.762405, "longitude": -122.20578, "is_bev": false, "range_category": "Short Range", "is_cafv_eligible": false}|
# |{"vin": "1C4RJYD61P", "county": "Yakima", "city": "Yakima", "state": "WA", "postal_code": "98908", "make": "JEEP", "model": "GRAND CHEROKEE", "electric_vehicle_type": "Plug-in Hybrid Electric Vehicle (PHEV)", "cafv_eligibility": "Not eligible due to low battery range", "electric_utility": "PACIFICORP", "model_year": 2023, "electric_range": 25, "base_msrp": 0, "legislative_district": 14, "dol_vehicle_id": 229675939, "census_tract": "53077002900", "latitude": 46.5965625, "longitude": -120.6027202, "is_bev": false, "range_category": "Short Range", "is_cafv_eligible": false}                              |
# |{"vin": "5YJ3E1EA7J", "county": "King", "city": "Kirkland", "state": "WA", "postal_code": "98034", "make": "TESLA", "model": "MODEL 3", "electric_vehicle_type": "Battery Electric Vehicle (BEV)", "cafv_eligibility": "Clean Alternative Fuel Vehicle Eligible", "electric_utility": "PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)", "model_year": 2018, "electric_range": 215, "base_msrp": 0, "legislative_district": 45, "dol_vehicle_id": 104714466, "census_tract": "53033021903", "latitude": 47.71124, "longitude": -122.209285, "is_bev": true, "range_category": "Long Range", "is_cafv_eligible": true}            |
# |{"vin": "WBY7Z8C5XJ", "county": "Thurston", "city": "Olympia", "state": "WA", "postal_code": "98501", "make": "BMW", "model": "I3", "electric_vehicle_type": "Plug-in Hybrid Electric Vehicle (PHEV)", "cafv_eligibility": "Clean Alternative Fuel Vehicle Eligible", "electric_utility": "PUGET SOUND ENERGY INC", "model_year": 2018, "electric_range": 97, "base_msrp": 0, "legislative_district": 22, "dol_vehicle_id": 185498386, "census_tract": "53067010700", "latitude": 47.043535, "longitude": -122.89692, "is_bev": false, "range_category": "Short Range", "is_cafv_eligible": true}                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 2. Read and Display EV Data
# Parse the Kafka messages and display the data.

# %%
# Parse the raw batch data into structured DataFrame
parsed_df = raw_batch.selectExpr("CAST(value AS STRING)") \
    .select(from_json(col("value"), ev_schema).alias("data")) \
    .select("data.*")

# Show sample data
print(f"Total parsed records: {parsed_df.count()}")
parsed_df.show(10, truncate=False)
# Out:
# Total parsed records: 633845
# +----------+---------+-----------+-----+-----------+--------+--------------+--------------------------------------+------------------------------------------------------------+---------------------------------------------+----------+--------------+---------+--------------------+--------------+------------+----------+------------+------+--------------+----------------+
# |vin       |county   |city       |state|postal_code|make    |model         |electric_vehicle_type                 |cafv_eligibility                                            |electric_utility                             |model_year|electric_range|base_msrp|legislative_district|dol_vehicle_id|census_tract|latitude  |longitude   |is_bev|range_category|is_cafv_eligible|
# +----------+---------+-----------+-----+-----------+--------+--------------+--------------------------------------+------------------------------------------------------------+---------------------------------------------+----------+--------------+---------+--------------------+--------------+------------+----------+------------+------+--------------+----------------+
# |KM8K33AGXL|King     |Seattle    |WA   |98103      |HYUNDAI |KONA          |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) |2020      |258           |0        |43                  |249675142     |53033004800 |47.659185 |-122.34301  |true  |Long Range    |true            |
# |1C4RJYB61N|King     |Bothell    |WA   |98011      |JEEP    |GRAND CHEROKEE|Plug-in Hybrid Electric Vehicle (PHEV)|Not eligible due to low battery range                       |PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|2022      |25            |0        |1                   |233928502     |53033021804 |47.762405 |-122.20578  |false |Short Range   |false           |
# |1C4RJYD61P|Yakima   |Yakima     |WA   |98908      |JEEP    |GRAND CHEROKEE|Plug-in Hybrid Electric Vehicle (PHEV)|Not eligible due to low battery range                       |PACIFICORP                                   |2023      |25            |0        |14                  |229675939     |53077002900 |46.5965625|-120.6027202|false |Short Range   |false           |
# |5YJ3E1EA7J|King     |Kirkland   |WA   |98034      |TESLA   |MODEL 3       |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|2018      |215           |0        |45                  |104714466     |53033021903 |47.71124  |-122.209285 |true  |Long Range    |true            |
# |WBY7Z8C5XJ|Thurston |Olympia    |WA   |98501      |BMW     |I3            |Plug-in Hybrid Electric Vehicle (PHEV)|Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC                       |2018      |97            |0        |22                  |185498386     |53067010700 |47.043535 |-122.89692  |false |Short Range   |true            |
# |5YJ3E1EAXL|Snohomish|Marysville |WA   |98271      |TESLA   |MODEL 3       |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC                       |2020      |266           |0        |38                  |124595523     |53061940001 |48.10433  |-122.1713847|true  |Long Range    |true            |
# |2C4RC1N77H|King     |Kent       |WA   |98042      |CHRYSLER|PACIFICA      |Plug-in Hybrid Electric Vehicle (PHEV)|Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|2017      |33            |0        |47                  |1815593       |53033031707 |47.36078  |-122.111625 |false |Short Range   |true            |
# |5YJYGDEE3L|King     |Woodinville|WA   |98072      |TESLA   |MODEL Y       |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|2020      |291           |0        |45                  |124760555     |53033021906 |47.75855  |-122.151665 |true  |Long Range    |true            |
# |5YJ3E1EA1J|Island   |Coupeville |WA   |98239      |TESLA   |MODEL 3       |Battery Electric Vehicle (BEV)        |Clean Alternative Fuel Vehicle Eligible                     |PUGET SOUND ENERGY INC                       |2018      |215           |0        |10                  |125048003     |53029971000 |48.2179983|-122.6880708|true  |Long Range    |true            |
# |7SAYGDEF0P|King     |Bellevue   |WA   |98004      |TESLA   |MODEL Y       |Battery Electric Vehicle (BEV)        |Eligibility unknown as battery range has not been researched|PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)|2023      |0             |0        |48                  |240416207     |53033023806 |47.61385  |-122.201905 |true  |Unknown       |NULL            |
# +----------+---------+-----------+-----+-----------+--------+--------------+--------------------------------------+------------------------------------------------------------+---------------------------------------------+----------+--------------+---------+--------------------+--------------+------------+----------+------------+------+--------------+----------------+
# only showing top 10 rows

# %% [markdown]
# ## 3. Top 3 Cities with Most Electric Cars in 2023
# Filter for model year 2023 and aggregate by city.

# %%
# Create temporary view for SQL queries
parsed_df.createOrReplaceTempView("electric_vehicles")

# Top 3 cities with most electric cars in 2023 using SQL
print("Top 3 cities with most electric cars in 2023:")
spark.sql("""
    SELECT city, COUNT(*) as ev_count
    FROM electric_vehicles
    WHERE model_year = 2023
    GROUP BY city
    ORDER BY ev_count DESC
    LIMIT 3
""").show(truncate=False)
# Out:
# Top 3 cities with most electric cars in 2023:
# +--------+--------+
# |city    |ev_count|
# +--------+--------+
# |Seattle |23726   |
# |Bellevue|9181    |
# |Tukwila |8375    |
# +--------+--------+
